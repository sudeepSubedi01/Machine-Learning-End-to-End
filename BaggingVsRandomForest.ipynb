# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1, random_state=42)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col15'])
df['target'] = y

print(df.shape)
print(df.head())
# Out:
# (100, 6)
#        col1      col2      col3      col4     col15  target
# 0  1.053909 -3.861208  1.530963  0.596692  1.030284       0
# 1  3.243492  1.666651  3.179016 -0.825861  0.778528       1
# 2  0.712446 -1.201617  1.528624 -0.422788 -0.376825       0
# 3  1.388329  1.538995  1.243716  0.740905 -2.081063       1
# 4  2.394647 -3.576345  0.914217  0.363136  2.110329       0

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

bag = BaggingClassifier(max_features=2)
bag.fit(df.iloc[:,0:5], df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
bag.estimators_
# Out:
# [DecisionTreeClassifier(random_state=1995066963),
#  DecisionTreeClassifier(random_state=1876871478),
#  DecisionTreeClassifier(random_state=864889037),
#  DecisionTreeClassifier(random_state=1722757205),
#  DecisionTreeClassifier(random_state=561245671),
#  DecisionTreeClassifier(random_state=120609398),
#  DecisionTreeClassifier(random_state=1082450730),
#  DecisionTreeClassifier(random_state=132228693),
#  DecisionTreeClassifier(random_state=1309351936),
#  DecisionTreeClassifier(random_state=770442498)]

# %%
bag.estimators_[0]
# Out:
# DecisionTreeClassifier(random_state=1995066963)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
# Out:
# [Text(0.5, 0.9285714285714286, 'x[0] <= -0.631\ngini = 0.49\nsamples = 63\nvalue = [43.0, 57.0]'),
#  Text(0.2727272727272727, 0.7857142857142857, 'x[1] <= 0.295\ngini = 0.05\nsamples = 23\nvalue = [38, 1]'),
#  Text(0.38636363636363635, 0.8571428571428572, 'True  '),
#  Text(0.18181818181818182, 0.6428571428571429, 'x[1] <= 0.247\ngini = 0.245\nsamples = 4\nvalue = [6, 1]'),
#  Text(0.09090909090909091, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]'),
#  Text(0.2727272727272727, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36363636363636365, 0.6428571428571429, 'gini = 0.0\nsamples = 19\nvalue = [32, 0]'),
#  Text(0.7272727272727273, 0.7857142857142857, 'x[0] <= 0.927\ngini = 0.15\nsamples = 40\nvalue = [5, 56]'),
#  Text(0.6136363636363636, 0.8571428571428572, '  False'),
#  Text(0.6363636363636364, 0.6428571428571429, 'x[0] <= 0.422\ngini = 0.33\nsamples = 16\nvalue = [5, 19]'),
# ...

# %% [markdown]
# Tree level sampling. Samples are decided at the root node.

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,0:5], df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
rf.estimators_[4]
# Out:
# DecisionTreeClassifier(max_features=2, random_state=1598582264)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[1])
plt.show()

# %% [markdown]
# Node level sampling.
